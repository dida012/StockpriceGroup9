# %% [markdown]
# #  Group 9
# ## Topic: Stock Price and Volume Data
# https://site.financialmodelingprep.com/developer/docs/stable/historical-price-eod-full

# %% [markdown]
# ### Problem Statement
# The objective of this project is to predict the daily closing stock price (close) of publicly traded companies using historical stock price and volume data obtained from the FinancialModelingPrep Stock Price and Volume Data API.
#
# The dataset contains daily trading indicators such as `open price, high price, low price, trading volume, price changes, and volume-weighted average price (VWAP)`. These indicators are used as input features to build machine learning regression models that estimate the stock’s closing price.
#
# ###### Why This Is a Real-World Problem
# This problem is highly relevant in real-world financial systems for several reasons:
#
# 1.Used in Finance and Trading Systems
#
# 2.Supports Investment and Risk Analysis
#
# 3.Improves Decision-Making in Stock Markets
#
# 4.Based on Real Market Data
#
#
#
# ###### Target Variable
# Target: close
#
# Represents the final traded price of a stock at the end of the trading day..
#
# ###### Machine Learning Problem Type
# Problem Type: Regression
#
# Reason:
#
# The target variable (close) is a continuous numerical value.
#
# The goal is to predict an exact price, not a category.

# %% [markdown]
# ## Import Required Libraries
#
# We start by importing the necessary Python libraries for making API requests and handling data.

# %%
import requests
import pandas as pd

api_key = "lnfGyrjPn5XQ0N4MG9vdvaf5zhrC1G7u"

stock_symbols = ["AAPL", "GOOGL", "MSFT", "META"]

# %% [markdown]
# ## Fetch Historical Stock Price Data
#
# We loop through each stock symbol and send a request to the Financial Modeling Prep API
#
# to retrieve historical end-of-day (EOD) price data within a specified date range.

# %%
all_data = []

for symbol in stock_symbols:
    url = "https://financialmodelingprep.com/stable/historical-price-eod/full"
    
    params = {
        "symbol": symbol,
        "from": "2024-01-01",
        "to": "2025-01-01",
        "apikey": api_key
    }
    
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        
        if len(data) > 0:
            df = pd.DataFrame(data)
            df["symbol"] = symbol
            all_data.append(df)
        else:
            print(f"No data for {symbol}")
    else:
        print(f"Error for {symbol}: {response.status_code}")

# %% [markdown]
# ## Inspect API Response (Formatted JSON)
#
# To better understand the structure of the data returned by the API,
#
# we format and print the JSON response using the `json` module.

# %%
import json
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "symbol": "META",
#     "date": "2024-12-31",
#     "open": 592.27,
#     "high": 593.97,
#     "low": 583.85,
#     "close": 585.51,
#     "volume": 6019520,
#     "change": -6.75,
#     "changePercent": -1.14,
#     "vwap": 588.9
#   },
#   {
#     "symbol": "META",
#     "date": "2024-12-30",
#     "open": 588.75,
#     "high": 596.94,
#     "low": 585.58,
#     "close": 591.24,
#     "volume": 7025900,
#     "change": 2.49,
#     "changePercent": 0.42293,
#     "vwap": 590.6275
#   },
#   {
#     "symbol": "META",
#     "date": "2024-12-27",
#     "open": 599.41,
#     "high": 601.85,
#     "low": 589.8,
#     "close": 599.81,
#     "volume": 8084229,
#     "change": 0.4,
#     "changePercent": 0.06673229,
#     "vwap": 597.7175
#   },
#   {
#     "symbol": "META",
#     "date": "2024-12-26",
#     "open": 605.48,
#     "high": 606.3,
#     "low": 598.94,
#     "close": 603.35,
#     "volume": 6091239,
#     "change": -2.13,
#     "changePercent": -0.35179,
#     "vwap": 603.5175
#   },
#   {
#     "symbol": "META",
#     "date": "2024-12

#   },
#   {
#     "symbol": "META",
#     "date": "2024-04-04",
#     "open": 516.42,
#     "high": 530,
#     "low": 510.58,
#     "close": 510.92,
#     "volume": 26476300,
#     "change": -5.5,
#     "changePercent": -1.07,
#     "vwap": 516.98
#   },
#   {
#     "symbol": "META",
#     "date": "2024-04-03",
#     "open": 498.93,
#     "high": 507.24,
#     "low": 498.75,
#     "close": 506.74,
#     "volume": 12099200,
#     "change": 7.81,
#     "changePercent": 1.57,
#     "vwap": 502.915
#   },
#   {
#     "symbol": "META",
#     "date": "2024-04-02",
#     "open": 485.1,
#     "high": 497.53,
#     "low": 484.65,
#     "close": 497.37,
#     "volume": 11081026,
#     "change": 12.27,
#     "changePercent": 2.53,
#     "vwap": 491.1625
#   },
#   {
#     "symbol": "META",
#     "date": "2024-04-01",
#     "open": 487.2,
#     "high": 497.43,
#     "low": 481.78,
#     "close": 491.35,
#     "volume": 9247007,
#     "change": 4.15,
#     "changePercent": 0.85181,
#     "vwap": 489.44
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-28",
#     "open": 492.84,
#     "high": 492.89,
#     "low": 485.15,
#     "close": 485.58,
#     "volume": 15212800,
#     "change": -7.26,
#     "changePercent": -1.47,
#     "vwap": 489.115
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-27",
#     "open": 499.3,
#     "high": 499.89,
#     "low": 488.07,
#     "close": 493.86,
#     "volume": 9989700,
#     "change": -5.44,
#     "changePercent": -1.09,
#     "vwap": 495.28
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-26",
#     "open": 505.13,
#     "high": 510,
#     "low": 495.21,
#     "close": 495.89,
#     "volume": 11205400,
#     "change": -9.24,
#     "changePercent": -1.83,
#     "vwap": 501.5575
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-25",
#     "open": 505.79,
#     "high": 507.22,
#     "low": 500.24,
#     "close": 503.02,
#     "volume": 8380617,
#     "change": -2.77,
#     "changePercent": -0.54766,
#     "vwap": 504.0675
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-22",
#     "open": 507,
#     "high": 509.97,
#     "low": 504.34,
#     "close": 509.58,
#     "volume": 8120600,
#     "change": 2.58,
#     "changePercent": 0.50888,
#     "vwap": 507.7225
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-21",
#     "open": 514.71,
#     "high": 515.04,
#     "low": 506.01,
#     "close": 507.76,
#     "volume": 9712549,
#     "change": -6.95,
#     "changePercent": -1.35,
#     "vwap": 510.88
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-20",
#     "open": 499.5,
#     "high": 508.2,
#     "low": 495.17,
#     "close": 505.52,
#     "volume": 11711100,
#     "change": 6.02,
#     "changePercent": 1.21,
#     "vwap": 502.0975
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-19",
#     "open": 488.17,
#     "high": 496.63,
#     "low": 481.28,
#     "close": 496.24,
#     "volume": 10903100,
#     "change": 8.07,
#     "changePercent": 1.65,
#     "vwap": 490.58
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-18",
#     "open": 491.91,
#     "high": 497.42,
#     "low": 486.81,
#     "close": 496.98,
#     "volume": 11755300,
#     "change": 5.07,
#     "changePercent": 1.03,
#     "vwap": 493.28
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-15",
#     "open": 489.01,
#     "high": 491.83,
#     "low": 481.3,
#     "close": 484.1,
#     "volume": 29153600,
#     "change": -4.91,
#     "changePercent": -1,
#     "vwap": 486.56
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-14",
#     "open": 500.26,
#     "high": 501.35,
#     "low": 488.16,
#     "close": 491.83,
#     "volume": 12620014,
#     "change": -8.43,
#     "changePercent": -1.69,
#     "vwap": 495.4
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-13",
#     "open": 495.39,
#     "high": 500.98,
#     "low": 491.03,
#     "close": 495.57,
#     "volume": 12090700,
#     "change": 0.18,
#     "changePercent": 0.03633501,
#     "vwap": 495.7425
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-12",
#     "open": 493.26,
#     "high": 502.31,
#     "low": 484.73,
#     "close": 499.75,
#     "volume": 15448232,
#     "change": 6.49,
#     "changePercent": 1.32,
#     "vwap": 495.0125
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-11",
#     "open": 497.01,
#     "high": 497.32,
#     "low": 476,
#     "close": 483.59,
#     "volume": 20428300,
#     "change": -13.42,
#     "changePercent": -2.7,
#     "vwap": 488.48
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-08",
#     "open": 514.19,
#     "high": 523.57,
#     "low": 499.35,
#     "close": 505.95,
#     "volume": 18597100,
#     "change": -8.24,
#     "changePercent": -1.6,
#     "vwap": 510.765
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-07",
#     "open": 503.28,
#     "high": 519.85,
#     "low": 501.38,
#     "close": 512.19,
#     "volume": 18586437,
#     "change": 8.91,
#     "changePercent": 1.77,
#     "vwap": 509.175
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-06",
#     "open": 497.63,
#     "high": 502.97,
#     "low": 494.29,
#     "close": 496.09,
#     "volume": 11757925,
#     "change": -1.54,
#     "changePercent": -0.30947,
#     "vwap": 497.745
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-05",
#     "open": 495,
#     "high": 495.58,
#     "low": 487.89,
#     "close": 490.22,
#     "volume": 15325300,
#     "change": -4.78,
#     "changePercent": -0.96566,
#     "vwap": 492.1725
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-04",
#     "open": 503,
#     "high": 504.42,
#     "low": 496.42,
#     "close": 498.19,
#     "volume": 12324141,
#     "change": -4.81,
#     "changePercent": -0.95626,
#     "vwap": 500.5075
#   },
#   {
#     "symbol": "META",
#     "date": "2024-03-01",
#     "open": 492.11,
#     "high": 504.25,
#     "low": 491.85,
#     "close": 502.3,
#     "volume": 16273600,
#     "change": 10.19,
#     "changePercent": 2.07,
#     "vwap": 497.6275
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-29",
#     "open": 488.44,
#     "high": 491.7,
#     "low": 482.61,
#     "close": 490.13,
#     "volume": 17732045,
#     "change": 1.69,
#     "changePercent": 0.346,
#     "vwap": 488.22
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-28",
#     "open": 485,
#     "high": 491.05,
#     "low": 482.75,
#     "close": 484.02,
#     "volume": 12715500,
#     "change": -0.98,
#     "changePercent": -0.20206,
#     "vwap": 485.705
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-27",
#     "open": 479.98,
#     "high": 487.27,
#     "low": 479.92,
#     "close": 487.05,
#     "volume": 10809600,
#     "change": 7.07,
#     "changePercent": 1.47,
#     "vwap": 483.555
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-26",
#     "open": 483.47,
#     "high": 486.14,
#     "low": 480.6,
#     "close": 481.74,
#     "volume": 12101415,
#     "change": -1.73,
#     "changePercent": -0.35783,
#     "vwap": 482.9875
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-23",
#     "open": 488.05,
#     "high": 494.36,
#     "low": 482.35,
#     "close": 484.03,
#     "volume": 18374300,
#     "change": -4.02,
#     "changePercent": -0.82369,
#     "vwap": 487.1975
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02-22",
#     "open": 480.24,
#     "high": 489.99,
#     "low": 476.06,
#     "close": 486.13,
#     "volume": 21625805,
#     "change": 5.89,
#     "changePercent": 1.23,
#     "vwap": 483.105
#   },
#   {
#     "symbol": "META",
#     "date": "2024-02
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-30",
#     "open": 403.59,
#     "high": 406.36,
#     "low": 399.57,
#     "close": 400.06,
#     "volume": 18614727,
#     "change": -3.53,
#     "changePercent": -0.87465,
#     "vwap": 402.395
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-29",
#     "open": 394.99,
#     "high": 402.93,
#     "low": 393.1,
#     "close": 401.02,
#     "volume": 18742433,
#     "change": 6.03,
#     "changePercent": 1.53,
#     "vwap": 398.01
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-26",
#     "open": 394.35,
#     "high": 396.79,
#     "low": 391.59,
#     "close": 394.14,
#     "volume": 13163700,
#     "change": -0.21,
#     "changePercent": -0.05325219,
#     "vwap": 394.2175
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-25",
#     "open": 390.17,
#     "high": 395.49,
#     "low": 385.66,
#     "close": 393.18,
#     "volume": 15091100,
#     "change": 3.01,
#     "changePercent": 0.77146,
#     "vwap": 391.125
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-24",
#     "open": 390,
#     "high": 396.15,
#     "low": 387.81,
#     "close": 390.7,
#     "volume": 15698500,
#     "change": 0.7,
#     "changePercent": 0.17949,
#     "vwap": 391.165
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-23",
#     "open": 384.62,
#     "high": 388.38,
#     "low": 382.08,
#     "close": 385.2,
#     "volume": 15506100,
#     "change": 0.585,
#     "changePercent": 0.1508,
#     "vwap": 385.07
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-22",
#     "open": 387.95,
#     "high": 390.35,
#     "low": 381.16,
#     "close": 381.78,
#     "volume": 17680500,
#     "change": -6.17,
#     "changePercent": -1.59,
#     "vwap": 385.31
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-19",
#     "open": 379,
#     "high": 384.36,
#     "low": 377.97,
#     "close": 383.45,
#     "volume": 21670806,
#     "change": 4.45,
#     "changePercent": 1.17,
#     "vwap": 381.195
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-18",
#     "open": 371.49,
#     "high": 376.85,
#     "low": 370.95,
#     "close": 376.13,
#     "volume": 16354332,
#     "change": 4.64,
#     "changePercent": 1.25,
#     "vwap": 373.855
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-17",
#     "open": 366.3,
#     "high": 368.54,
#     "low": 358.61,
#     "close": 368.37,
#     "volume": 12724800,
#     "change": 2.07,
#     "changePercent": 0.56511,
#     "vwap": 365.455
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-16",
#     "open": 373.65,
#     "high": 375.61,
#     "low": 367.23,
#     "close": 367.46,
#     "volume": 15306900,
#     "change": -6.19,
#     "changePercent": -1.66,
#     "vwap": 370.9875
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-12",
#     "open": 370.16,
#     "high": 377.06,
#     "low": 369.54,
#     "close": 374.49,
#     "volume": 19310046,
#     "change": 4.34,
#     "changePercent": 1.17,
#     "vwap": 372.8125
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-11",
#     "open": 372.13,
#     "high": 372.78,
#     "low": 362.93,
#     "close": 369.67,
#     "volume": 17205400,
#     "change": -2.46,
#     "changePercent": -0.66106,
#     "vwap": 369.3775
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-10",
#     "open": 360.17,
#     "high": 372.94,
#     "low": 359.08,
#     "close": 370.47,
#     "volume": 22117206,
#     "change": 10.3,
#     "changePercent": 2.86,
#     "vwap": 365.665
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-09",
#     "open": 356.4,
#     "high": 360.64,
#     "low": 355.36,
#     "close": 357.43,
#     "volume": 13463900,
#     "change": 1.03,
#     "changePercent": 0.289,
#     "vwap": 357.4575
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-08",
#     "open": 354.7,
#     "high": 358.98,
#     "low": 352.05,
#     "close": 358.66,
#     "volume": 13890222,
#     "change": 3.96,
#     "changePercent": 1.12,
#     "vwap": 356.0975
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-05",
#     "open": 346.99,
#     "high": 353.5,
#     "low": 346.26,
#     "close": 351.95,
#     "volume": 13920700,
#     "change": 4.96,
#     "changePercent": 1.43,
#     "vwap": 349.675
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-04",
#     "open": 344.5,
#     "high": 348.15,
#     "low": 343.4,
#     "close": 347.12,
#     "volume": 12099900,
#     "change": 2.62,
#     "changePercent": 0.76052,
#     "vwap": 345.7925
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-03",
#     "open": 344.98,
#     "high": 347.95,
#     "low": 343.18,
#     "close": 344.47,
#     "volume": 15451133,
#     "change": -0.51,
#     "changePercent": -0.14783,
#     "vwap": 345.145
#   },
#   {
#     "symbol": "META",
#     "date": "2024-01-02",
#     "open": 351.32,
#     "high": 353.16,
#     "low": 340.01,
#     "close": 346.29,
#     "volume": 19042200,
#     "change": -5.03,
#     "changePercent": -1.43,
#     "vwap": 347.695
#   }
# ]

# %% [markdown]
# ## Fetch Historical Stock Data for Multiple Symbols
#
# We loop through each stock symbol, request historical end-of-day (EOD) data from the API, and store all records in a single list.

# %%
all_data = []

for symbol in stock_symbols:
    url = "https://financialmodelingprep.com/stable/historical-price-eod/full"
    params = {
        "symbol": symbol,
        "apikey": api_key
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()

        for stock in data:
            stock["symbol"] = symbol  # ensure symbol exists
            all_data.append(stock)

# %% [markdown]
# ## Verify Stock Symbols in the Retrieved Data
#
# Before proceeding with analysis, we confirm that all requested stock symbols are present in the collected data.

# %%
# Ensuring all the Stores' symbols are in the data requested
symbols_in_data = list(set(stock["symbol"] for stock in all_data))
print(symbols_in_data)
# Out:
# ['MSFT', 'AAPL', 'GOOGL', 'META']

# %% [markdown]
# ## Rename Stock Symbols for Better Readability
#
# To improve clarity and presentation, we map stock ticker symbols to more descriptive company names.

# %%
renaming_symbols = {
    'GOOG': 'GOOGLE',
    'META': 'META',
    'AAPL': 'APPLE',
    'MSFT':'MICROSOFT'
}

renamed_symbols = [renaming_symbols.get(sym, sym) for sym in symbols_in_data]
print(renamed_symbols)
# Out:
# ['MICROSOFT', 'APPLE', 'GOOGL', 'META']

# %% [markdown]
# ## Create and Clean the Final DataFrame
#
# In this step, we consolidate the collected stock data into a single pandas DataFrame and apply basic cleaning and formatting.

# %%
all_data = []

for daily_data in data:
    all_data.append(daily_data)

df = pd.DataFrame(all_data)

df["symbol"] = df["symbol"].replace(renaming_symbols)

df["date"] = pd.to_datetime(df["date"])

df = df.sort_values(by=["symbol", "date"]).reset_index(drop=True)

print(df)
# Out:
#      symbol       date    open    high     low    close    volume  change  \
# 0      META 2021-01-08  268.31  268.95  263.18  267.570  18528300   -0.74
# 1      META 2021-01-11  260.48  263.47  255.90  256.840  30412300   -3.64
# 2      META 2021-01-12  256.63  259.72  250.30  251.090  26449943   -5.54
# 3      META 2021-01-13  251.55  253.95  249.20  251.640  19528938    0.09
# 4      META 2021-01-14  253.40  255.03  244.61  245.640  29739404   -7.76
# ...     ...        ...     ...     ...     ...      ...       ...     ...
# 1250   META 2025-12-31  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251   META 2026-01-02  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252   META 2026-01-05  651.01  664.54  647.75  658.790  12213745    7.78
# 1253   META 2026-01-06  659.57  665.52  651.90  660.620  11074419    1.05
# 1254   META 2026-01-07  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap
# 0         -0.275800  267.0025
# 1         -1.400000  259.1725
# 2         -2.160000  254.4350
# 3          0.035778  251.5850
# 4         -3.060000  249.6700
# ...             ...       ...
# 1250      -0.701020  662.3200
# 1251      -1.860000  655.2575
# 1252       1.200000  655.5225
# 1253       0.159190  659.4025
# 1254      -0.845558  651.4000
#
# [1255 rows x 10 columns]

# %% [markdown]
# ## Inspect DataFrame Columns
#
# Before performing further cleaning or analysis, we list all column names in the DataFrame to understand its structure.

# %%
print(df.columns.tolist())
# Out:
# ['symbol', 'date', 'open', 'high', 'low', 'close', 'volume', 'change', 'changePercent', 'vwap']

# %% [markdown]
# ## Select Columns of Interest
#
# To focus the analysis on relevant features, we define a list of columns that are important for financial and time-series analysis.

# %%
columns_of_interest = [
    'date', 'symbol', 'open', 'high', 'low', 'close',
    'adjClose', 'volume', 'unadjustedVolume',
    'change', 'changePercent', 'vwap',
    'label', 'changeOverTime'
]

# Reindex safely — missing columns will be added as NaN
df = df.reindex(columns=columns_of_interest)
df
# Out:
#            date symbol    open    high     low    close  adjClose    volume  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570       NaN  18528300
# 1    2021-01-11   META  260.48  263.47  255.90  256.840       NaN  30412300
# 2    2021-01-12   META  256.63  259.72  250.30  251.090       NaN  26449943
# 3    2021-01-13   META  251.55  253.95  249.20  251.640       NaN  19528938
# 4    2021-01-14   META  253.40  255.03  244.61  245.640       NaN  29739404
# ...         ...    ...     ...     ...     ...      ...       ...       ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090       NaN   7940400
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410       NaN  13726517
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790       NaN  12213745
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620       NaN  11074419
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235       NaN   5169178
#
#       unadjustedVolume  change  changePercent      vwap  label  changeOverTime
# 0                  NaN   -0.74      -0.275800  267.0025    NaN             NaN
# 1                  NaN   -3.64      -1.400000  259.1725    NaN             NaN
# 2                  NaN   -5.54      -2.160000  254.4350    NaN             NaN
# 3                  NaN    0.09       0.035778  251.5850    NaN             NaN
# 4                  NaN   -7.76      -3.060000  249.6700    NaN             NaN
# ...                ...     ...            ...       ...    ...             ...
# 1250               NaN   -4.66      -0.701020  662.3200    NaN             NaN
# 1251               NaN  -12.32      -1.860000  655.2575    NaN             NaN
# 1252               NaN    7.78       1.200000  655.5225    NaN             NaN
# 1253               NaN    1.05       0.159190  659.4025    NaN             NaN
# 1254               NaN   -5.54      -0.845558  651.4000    NaN             NaN
#
# [1255 rows x 14 columns]

# %% [markdown]
# ## Inspect DataFrame Columns
#
# Before performing further cleaning or analysis, we list all column names in the DataFrame to understand its structure.

# %%
print(df.columns.tolist())
# Out:
# ['date', 'symbol', 'open', 'high', 'low', 'close', 'adjClose', 'volume', 'unadjustedVolume', 'change', 'changePercent', 'vwap', 'label', 'changeOverTime']

# %% [markdown]
# ## Drop Unnecessary Columns
#
# To simplify the dataset and focus on the most relevant variables, we remove columns that are not required for the analysis.

# %%
df = df.drop(columns=['adjClose', 'unadjustedVolume', 'label', 'changeOverTime'], errors='ignore')
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap
# 0         -0.275800  267.0025
# 1         -1.400000  259.1725
# 2         -2.160000  254.4350
# 3          0.035778  251.5850
# 4         -3.060000  249.6700
# ...             ...       ...
# 1250      -0.701020  662.3200
# 1251      -1.860000  655.2575
# 1252       1.200000  655.5225
# 1253       0.159190  659.4025
# 1254      -0.845558  651.4000
#
# [1255 rows x 10 columns]

# %% [markdown]
# ## Check for Missing Values
#
# Before analysis, it is important to verify whether the dataset contains any empty or missing cells.

# %%
df.isnull().sum().sum() # Checking is there is any empyty cell
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap
# 0         -0.275800  267.0025
# 1         -1.400000  259.1725
# 2         -2.160000  254.4350
# 3          0.035778  251.5850
# 4         -3.060000  249.6700
# ...             ...       ...
# 1250      -0.701020  662.3200
# 1251      -1.860000  655.2575
# 1252       1.200000  655.5225
# 1253       0.159190  659.4025
# 1254      -0.845558  651.4000
#
# [1255 rows x 10 columns]

# %% [markdown]
# ## Calculate Cumulative Returns (`changeOverTime`)
#
# We calculate the percentage change in stock prices relative to the first available date for each stock.
# This helps analyze **relative performance over time**.

# %%
#Use group_keys=False in groupby
df['changeOverTime'] = (
    df.groupby('symbol', group_keys=False)['close']
      .apply(lambda x: (x / x.iloc[0]) - 1)
)
#Use transform instead of apply (simpler and faster)
df['changeOverTime'] = df.groupby('symbol')['close'].transform(lambda x: (x / x.iloc[0]) - 1)
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap  changeOverTime
# 0         -0.275800  267.0025        0.000000
# 1         -1.400000  259.1725       -0.040102
# 2         -2.160000  254.4350       -0.061591
# 3          0.035778  251.5850       -0.059536
# 4         -3.060000  249.6700       -0.081960
# ...             ...       ...             ...
# 1250      -0.701020  662.3200        1.466981
# 1251      -1.860000  655.2575        1.430803
# 1252       1.200000  655.5225        1.462122
# 1253       0.159190  659.4025        1.468961
# 1254      -0.845558  651.4000        1.430149
#
# [1255 rows x 11 columns]

# %% [markdown]
# ## Create a Formatted Date Label
#
# To make dates easier to read and use in charts or reports, we create a new column called `label` with a string representation of the date.

# %%
df['label'] = df['date'].dt.strftime('%Y-%m-%d')
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap  changeOverTime       label
# 0         -0.275800  267.0025        0.000000  2021-01-08
# 1         -1.400000  259.1725       -0.040102  2021-01-11
# 2         -2.160000  254.4350       -0.061591  2021-01-12
# 3          0.035778  251.5850       -0.059536  2021-01-13
# 4         -3.060000  249.6700       -0.081960  2021-01-14
# ...             ...       ...             ...         ...
# 1250      -0.701020  662.3200        1.466981  2025-12-31
# 1251      -1.860000  655.2575        1.430803  2026-01-02
# 1252       1.200000  655.5225        1.462122  2026-01-05
# 1253       0.159190  659.4025        1.468961  2026-01-06
# 1254      -0.845558  651.4000        1.430149  2026-01-07
#
# [1255 rows x 12 columns]

# %% [markdown]
# ## Create `unadjustedVolume` Column
#
# Sometimes it is useful to retain the original trading volume before any adjustments.
# We create a new column `unadjustedVolume` by copying the values from the existing `volume` column.

# %%
df['unadjustedVolume'] = df['volume']
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap  changeOverTime       label  unadjustedVolume
# 0         -0.275800  267.0025        0.000000  2021-01-08          18528300
# 1         -1.400000  259.1725       -0.040102  2021-01-11          30412300
# 2         -2.160000  254.4350       -0.061591  2021-01-12          26449943
# 3          0.035778  251.5850       -0.059536  2021-01-13          19528938
# 4         -3.060000  249.6700       -0.081960  2021-01-14          29739404
# ...             ...       ...             ...         ...               ...
# 1250      -0.701020  662.3200        1.466981  2025-12-31           7940400
# 1251      -1.860000  655.2575        1.430803  2026-01-02          13726517
# 1252       1.200000  655.5225        1.462122  2026-01-05          12213745
# 1253       0.159190  659.4025        1.468961  2026-01-06          11074419
# 1254      -0.845558  651.4000        1.430149  2026-01-07           5169178
#
# [1255 rows x 13 columns]

# %% [markdown]
# ## Create `adjClose` Column
#
# To retain a column for **adjusted close prices**, we create a new column `adjClose` by copying the existing `close` column.

# %%
df['adjClose'] = df['close']
df
# Out:
#            date symbol    open    high     low    close    volume  change  \
# 0    2021-01-08   META  268.31  268.95  263.18  267.570  18528300   -0.74
# 1    2021-01-11   META  260.48  263.47  255.90  256.840  30412300   -3.64
# 2    2021-01-12   META  256.63  259.72  250.30  251.090  26449943   -5.54
# 3    2021-01-13   META  251.55  253.95  249.20  251.640  19528938    0.09
# 4    2021-01-14   META  253.40  255.03  244.61  245.640  29739404   -7.76
# ...         ...    ...     ...     ...     ...      ...       ...     ...
# 1250 2025-12-31   META  664.75  665.00  659.44  660.090   7940400   -4.66
# 1251 2026-01-02   META  662.73  664.39  643.50  650.410  13726517  -12.32
# 1252 2026-01-05   META  651.01  664.54  647.75  658.790  12213745    7.78
# 1253 2026-01-06   META  659.57  665.52  651.90  660.620  11074419    1.05
# 1254 2026-01-07   META  655.78  659.15  644.81  650.235   5169178   -5.54
#
#       changePercent      vwap  changeOverTime       label  unadjustedVolume  \
# 0         -0.275800  267.0025        0.000000  2021-01-08          18528300
# 1         -1.400000  259.1725       -0.040102  2021-01-11          30412300
# 2         -2.160000  254.4350       -0.061591  2021-01-12          26449943
# 3          0.035778  251.5850       -0.059536  2021-01-13          19528938
# 4         -3.060000  249.6700       -0.081960  2021-01-14          29739404
# ...             ...       ...             ...         ...               ...
# 1250      -0.701020  662.3200        1.466981  2025-12-31           7940400
# 1251      -1.860000  655.2575        1.430803  2026-01-02          13726517
# 1252       1.200000  655.5225        1.462122  2026-01-05          12213745
# 1253       0.159190  659.4025        1.468961  2026-01-06          11074419
# 1254      -0.845558  651.4000        1.430149  2026-01-07           5169178
#
#       adjClose
# 0      267.570
# 1      256.840
# 2      251.090
# 3      251.640
# 4      245.640
# ...        ...
# 1250   660.090
# 1251   650.410
# 1252   658.790
# 1253   660.620
# 1254   650.235
#
# [1255 rows x 14 columns]

# %% [markdown]
# ## Save the Cleaned Dataset to CSV
#
# After all cleaning, formatting, and calculations, we export the final DataFrame to a CSV file for future use.

# %%
df.to_csv("clean_stock_data.csv", index=False)
